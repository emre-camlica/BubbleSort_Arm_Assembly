# %%
import matplotlib.pyplot as plt
values = [0,1, 2, 3, 5,6,8,11,14,16,20,23,27,31,36,41,46,52,57,63,70,76,83,91,98,106,114,122,131,140,150,160,170,181,192,204,216,
          227,239,251,264,276,288,301,314,329,342,357,372,388,402,417,433,450,465,480,498,514,532,549,569,587,604,624,
          644,663,682,701,723,746,767,790,813,837,857,882,903,924,946,970,995,1021,1045,1070,1097,1122,1150,1177,1203,
          1229,1253,1281,1311,1339,1369,1395,1424,1454,1485,1513]

numbers = list(range(1, 101))

plt.scatter(numbers, values)
plt.xlabel('Array size')
plt.ylabel('Time taken (µs)')
plt.title("Bubblesort Running Time - Array Size")
plt.show()
